# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt

# %%
matrix = np.random.rand(10,20)
matrix.shape
# Out:
# (10, 20)

# %%
print(matrix.mean().shape)
print(matrix.mean(axis=0).shape)
print(matrix.mean(axis=1).shape)
# Out:
# ()
# (20,)
# (10,)

# %%
plt.plot(matrix.mean(axis=0))
